# %%
import pandas as pd
from numpy import percentile
import statistics

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("C:\\Users\\Rupali\\Desktop\\Machine Learning\\Odd2020\\iris.csv")

# %%
df[['SL','PL']]
# Out:
#       SL   PL
# 0    5.1  1.4
# 1    4.9  1.4
# 2    4.7  1.3
# 3    4.6  1.5
# 4    5.0  1.4
# 5    5.4  1.7
# 6    4.6  1.4
# 7    5.0  1.5
# 8    4.4  1.4
# 9    4.9  1.5
# 10   5.4  1.5
# 11   4.8  1.6
# 12   4.8  1.4
# 13   4.3  1.1
# 14   5.8  1.2
# 15   5.7  1.5
# 16   5.4  1.3
# 17   5.1  1.4
# 18   5.7  1.7
# 19   5.1  1.5
# 20   5.4  1.7
# 21   5.1  1.5
# 22   4.6  1.0
# 23   5.1  1.7
# 24   4.8  1.9
# 25   5.0  1.6
# 26   5.0  1.6
# 27   5.2  1.5
# 28   5.2  1.4
# 29   4.7  1.6
# ..   ...  ...
# 120  6.9  5.7
# 121  5.6  4.9
# 122  7.7  6.7
# 123  6.3  4.9
# 124  6.7  5.7
# 125  7.2  6.0
# 126  6.2  4.8
# 127  6.1  4.9
# 128  6.4  5.6
# 129  7.2  5.8
# 130  7.4  6.1
# 131  7.9  6.4
# 132  6.4  5.6
# 133  6.3  5.1
# 134  6.1  5.6
# 135  7.7  6.1
# 136  6.3  5.6
# 137  6.4  5.5
# 138  6.0  4.8
# 139  6.9  5.4
# 140  6.7  5.6
# 141  6.9  5.1
# 142  5.8  5.1
# 143  6.8  5.9
# 144  6.7  5.7
# 145  6.7  5.2
# 146  6.3  5.0
# 147  6.5  5.2
# 148  6.2  5.4
# 149  5.9  5.1
#
# ...

# %%
quartiles = percentile(df['SL'], [25, 50, 75])

# %%
data_min, data_max = df['SL'].min(), df['SL'].max()

# %%
data_min, data_max
# Out:
# (4.3, 7.9)

# %%
print('Min: %.3f' % data_min)
print('Q1: %.3f' % quartiles[0])
print('Median: %.3f' % quartiles[1])
print('Q3: %.3f' % quartiles[2])
print('Max: %.3f' % data_max)
# Out:
# Min: 4.300
# Q1: 5.100
# Median: 5.800
# Q3: 6.400
# Max: 7.900

# %%
Iris_setosa = df[df['Class']=='Iris-setosa']['SL']
Iris_versicolor = df[df['Class']=='Iris-versicolor']['SL']
Iris_virginica = df[df['Class']=='Iris-virginica']['SL']

# %%
Iris_setosa = df[df['Class']=='Iris-setosa']

# %%
Iris_setosa
# Out:
#      SL   SW   PL   PW        Class
# 0   5.1  3.5  1.4  0.2  Iris-setosa
# 1   4.9  3.0  1.4  0.2  Iris-setosa
# 2   4.7  3.2  1.3  0.2  Iris-setosa
# 3   4.6  3.1  1.5  0.2  Iris-setosa
# 4   5.0  3.6  1.4  0.2  Iris-setosa
# 5   5.4  3.9  1.7  0.4  Iris-setosa
# 6   4.6  3.4  1.4  0.3  Iris-setosa
# 7   5.0  3.4  1.5  0.2  Iris-setosa
# 8   4.4  2.9  1.4  0.2  Iris-setosa
# 9   4.9  3.1  1.5  0.1  Iris-setosa
# 10  5.4  3.7  1.5  0.2  Iris-setosa
# 11  4.8  3.4  1.6  0.2  Iris-setosa
# 12  4.8  3.0  1.4  0.1  Iris-setosa
# 13  4.3  3.0  1.1  0.1  Iris-setosa
# 14  5.8  4.0  1.2  0.2  Iris-setosa
# 15  5.7  4.4  1.5  0.4  Iris-setosa
# 16  5.4  3.9  1.3  0.4  Iris-setosa
# 17  5.1  3.5  1.4  0.3  Iris-setosa
# 18  5.7  3.8  1.7  0.3  Iris-setosa
# 19  5.1  3.8  1.5  0.3  Iris-setosa
# 20  5.4  3.4  1.7  0.2  Iris-setosa
# 21  5.1  3.7  1.5  0.4  Iris-setosa
# 22  4.6  3.6  1.0  0.2  Iris-setosa
# 23  5.1  3.3  1.7  0.5  Iris-setosa
# 24  4.8  3.4  1.9  0.2  Iris-setosa
# ...

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.boxplot([Iris_setosa,Iris_versicolor,Iris_virginica], labels=['Setosa', 'Versicolor','Virginica'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1fcbcff3390>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1fcbcff3c50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1fcbcff3240>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1fcbd0054e0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1fcbd005908>,
# ...
#  'means': []}

# %%
x = statistics.mean(Iris_virginica)

# %%
print(x)
# Out:
# 6.588

# %%
y = statistics.stdev(Iris_virginica)

# %%
y
# Out:
# 0.6358795932744321

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# An "interface" to matplotlib.axes.Axes.hist() method
n, bins, patches = plt.hist(x=df['SL'], bins='auto', color='#0504aa',
                            alpha=0.7, rwidth=0.85)
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('My Very Own Histogram')
#plt.text(23, 45, r'$\mu=15, b=3$')
maxfreq = n.max()
# Set a clean upper y-axis limit.
plt.ylim(ymax=np.ceil(maxfreq / 10) * 10 if maxfreq % 10 else maxfreq + 10)
# Out:
# (0.0, 30.0)

# %%
plt.scatter(df['SL'],df['PL'])
plt.xlabel('sepal length (cm)')
plt.ylabel('petal length (cm)')
plt.title('Iris dataset: petal length vs sepal length')
plt.legend(loc='lower right')

plt.show()

# %%
colours = ['red', 'orange', 'blue']
species = ['Iris-setosa','Iris-versicolor', 'Iris-virginica']

for i in range (0,3):    
    species_df = df[df['Class'] == species[i]]    
    plt.scatter(        
        species_df['SL'],        
        species_df['PL'],
        color=colours[i],        
        alpha=0.5,        
        label=species[i]   
    )

plt.xlabel('sepal length (cm)')
plt.ylabel('petal length (cm)')
plt.title('Iris dataset: petal length vs sepal length')
plt.legend(loc='lower right')

plt.show()

# %%
df['Class'].value_counts().plot(kind='bar')
